# %% [markdown]
# # Proposal to Enable Fast TPN Calculations
#
# In this notebook solution direction is explored to enable Total Parenteral Nutrition calculations, like:
#
# tot_fluid = prot_fluid + sodium_fluid + potassium_fluid + gluc_fluid
#
# Each of those fluids can vary between, say, 0.1–500 mL, so each one easily has 100+ possible values. Combine two or more, and you quickly get a quadratic explosion in combinations.
#
# But in practice, we usually want answers to much vaguer questions — like “raise the drip by 10%.” It turns out this fits really nicely with how GenSolver can just calculate min and max values. For discrete variables (like fluid volumes or drip rates), it’s straightforward to set a value as a percentage of the total range of options.

# %%
// set up the environment
#load "load.fsx"

open System
open MathNet.Numerics
open Informedica.Utils.Lib.BCL
open Informedica.GenCore.Lib.Ranges
open Informedica.GenForm.Lib
open Informedica.GenUnits.Lib
open Informedica.GenOrder.Lib

Environment.SetEnvironmentVariable("GENPRES_DEBUG", "1")
Environment.SetEnvironmentVariable("GENPRES_PROD", "1")
Environment.SetEnvironmentVariable("GENPRES_URL_ID", "1JHOrasAZ_2fcVApYpt1qT2lZBsqrAxN-9SvBisXkbsM")


let print sl = sl |> List.iter (printfn "%s")

// optional use of a logger to dump all calculations
// to the console
let logger = OrderLogging.createConsoleLogger ()

# %% [markdown]
# Some helper functions to enable "cherry picking" the application of constraints on the TPN medication types.

# %%
// setting up some basic tpn constraints
let tpnConstraints =
    [
        OrderAdjust OrderVariable.Quantity.applyConstraints

        ScheduleFrequency OrderVariable.Frequency.applyConstraints
        ScheduleTime OrderVariable.Time.applyConstraints

        OrderableQuantity OrderVariable.Quantity.applyConstraints
        OrderableDoseCount OrderVariable.Count.applyConstraints
        OrderableDose Order.Orderable.Dose.applyConstraints

        ComponentOrderableQuantity ("", OrderVariable.Quantity.applyConstraints)

        ItemComponentConcentration ("", "", OrderVariable.Concentration.applyConstraints)
        ItemOrderableConcentration ("", "", OrderVariable.Concentration.applyConstraints)
    ]


// apply a change in the order property
let applyPropChange msg propChange ord =
    printfn $"=== Apply PropChange {msg} ==="
    let ord =
        ord
        |> Order.OrderPropertyChange.proc propChange
    ord
    |> Order.solveMinMax true Logging.noOp
    |> function
        | Ok ord -> ord
        | _ ->
            printfn $"=== ERROR {msg} ==="
            ord
    |> fun ord ->
        ord
        |> Order.printTable ConsoleTables.Format.Minimal

        ord


// run a tpn scenario with specific
// percentages for protein, potassium, sodium and glucose
let run 
    proteinPerc 
    potassiumPerc 
    sodiumPerc 
    glucPerc 
    tpn =
    
    tpn
    |> Medication.toOrderDto
    |> Order.Dto.fromDto
    |> Result.map (fun ord ->
        let ord =
            ord
            |> Order.OrderPropertyChange.proc tpnConstraints
    //        |> Order.applyConstraints

        ord
        |> Order.printTable ConsoleTables.Format.Minimal

        let ord =
            ord
            |> Order.solveMinMax true Logging.noOp //logger
            //|> Result.bind (Order.solveMinMax true logger)

        ord
        |> Result.iter (Order.printTable ConsoleTables.Format.Minimal)

        let ord =
            ord
            |> Result.map (fun ord ->
                ord
                |> applyPropChange
                    "Samenstelling C"
                    [
                        ComponentOrderableQuantity ("Samenstelling C", OrderVariable.Quantity.setPercValue proteinPerc)
                    ]
            )

        let ord =
            ord
            |> Result.map (fun ord ->
                ord
                |> applyPropChange
                    "KCl 7,4%"
                    [
                        ComponentOrderableQuantity ("KCl 7,4%", OrderVariable.Quantity.setPercValue potassiumPerc)
                    ]
            )

        let ord =
            ord
            |> Result.map (fun ord ->
                ord
                |> applyPropChange
                    "NaCl 3%"
                    [
                        ComponentOrderableQuantity ("NaCl 3%", OrderVariable.Quantity.setPercValue sodiumPerc)
                    ]
            )

        let ord =
            ord
            |> Result.map (fun ord ->
                ord
                |> applyPropChange
                    "gluc 10%"
                    [
                        ComponentOrderableQuantity ("gluc 10%", OrderVariable.Quantity.setPercValue glucPerc)
                    ]
            )

        ord
    )

# %% [markdown]
# Define 2 types of TPN solutions, a simple one and a more complex one.

# %%
// "simple TPN solution"
let tpnSimple =
    { Medication.order with
        Id = "f1adf475-919b-4b7d-9e26-6cc502b88e42"
        Name = "samenstelling c"
        Route = "INTRAVENEUS"
        OrderType = TimedOrder
        Adjust =
            11N
            |> ValueUnit.singleWithUnit Units.Weight.kiloGram
            |> Some
        AdjustUnit = Units.Weight.kiloGram |> Some
        Frequencies =
            1N
            |> ValueUnit.singleWithUnit (Units.Count.times |> Units.per Units.Time.day)
            |> Some
        Time =
            { MinMax.empty with
                Min =
                    20N
                    |> ValueUnit.singleWithUnit Units.Time.hour
                    |> Limit.inclusive
                    |> Some
                Max =
                    24N
                    |> ValueUnit.singleWithUnit Units.Time.hour
                    |> Limit.inclusive
                    |> Some
            }
        Dose =
            { DoseLimit.limit with
                DoseLimitTarget = "vloeistof" |> LimitTarget.FormLimitTarget
                AdjustUnit = Units.Weight.kiloGram |> Some
                QuantityAdjust =
                    { MinMax.empty with
                        Max =
                            (755N / 10N)
                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                            |> Limit.inclusive
                            |> Some
                    }
            }
            |> Some
        DoseCount =
            { MinMax.empty with
                Min = 1N |> ValueUnit.singleWithUnit Units.Count.times |> Limit.inclusive |> Some
                Max = 1N |> ValueUnit.singleWithUnit Units.Count.times |> Limit.inclusive |> Some
            }
        Components =
            [
                // Samenstelling C component
                {
                    Medication.productComponent with
                        Name = "Samenstelling C"
                        Form = "vloeistof"
                        Quantities =
                            1N
                            |> ValueUnit.singleWithUnit Units.Volume.milliLiter
                            |> Some
                        Divisible = Some (1N)
                        Dose =
                            { DoseLimit.limit with
                                DoseLimitTarget = "Samenstelling C" |> LimitTarget.ComponentLimitTarget
                                AdjustUnit = Units.Weight.kiloGram |> Some
                                QuantityAdjust =
                                    { MinMax.empty with
                                        Min =
                                            10N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                        Max =
                                            25N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                    }
                            }
                            |> Some
                        Substances =
                            [
                                {
                                    Medication.substanceItem with
                                        Name = "eiwit"
                                        Concentrations =
                                            (8N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Mass.gram |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "eiwit" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 100N)
                                                            |> ValueUnit.singleWithUnit (Units.Mass.gram |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "natrium"
                                        Concentrations =
                                            (1N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "natrium" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 10N)
                                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "kalium"
                                        Concentrations =
                                            (2N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "kalium" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 10N)
                                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                            ]
                }
                // NaCl 3% component
                {
                    Medication.productComponent with
                        Name = "NaCl 3%"
                        Form = "vloeistof"
                        Quantities =
                            1N
                            |> ValueUnit.singleWithUnit Units.Volume.milliLiter
                            |> Some
                        Divisible = Some (1N)
                        Dose =
                            { DoseLimit.limit with
                                DoseLimitTarget = "NaCl 3%" |> LimitTarget.ComponentLimitTarget
                                AdjustUnit = Units.Weight.kiloGram |> Some
                                QuantityAdjust =
                                    { MinMax.empty with
                                        Min =
                                            6N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                        Max =
                                            6N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                    }
                            }
                            |> Some
                        Substances =
                            [
                                {
                                    Medication.substanceItem with
                                        Name = "natrium"
                                        Concentrations =
                                            (5N / 10N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "natrium" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 10N)
                                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                            ]
                }
                // KCl 7,4% component
                {
                    Medication.productComponent with
                        Name = "KCl 7,4%"
                        Form = "vloeistof"
                        Quantities =
                            1N
                            |> ValueUnit.singleWithUnit Units.Volume.milliLiter
                            |> Some
                        Divisible = Some (1N)
                        Dose =
                            { DoseLimit.limit with
                                DoseLimitTarget = "KCl 7,4%" |> LimitTarget.ComponentLimitTarget
                                AdjustUnit = Units.Weight.kiloGram |> Some
                                QuantityAdjust =
                                    { MinMax.empty with
                                        Min =
                                            2N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                        Max =
                                            2N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                    }
                            }
                            |> Some
                        Substances =
                            [
                                {
                                    Medication.substanceItem with
                                        Name = "kalium"
                                        Concentrations =
                                            1N
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "kalium" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 10N)
                                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                            ]
                }
                // gluc 10% component
                {
                    Medication.productComponent with
                        Name = "gluc 10%"
                        Form = "vloeistof"
                        Quantities =
                            1N
                            |> ValueUnit.singleWithUnit Units.Volume.milliLiter
                            |> Some
                        Divisible = Some (1N)
                        Substances =
                            [
                                {
                                    Medication.substanceItem with
                                        Name = "koolhydraat"
                                        Concentrations =
                                            (1N / 10N)
                                            |> ValueUnit.singleWithUnit (Units.Mass.gram |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                            ]
                }
            ]
    }

// print out the tpn
tpnSimple
|> Medication.toString
|> print
# Out:
# Id: f1adf475-919b-4b7d-9e26-6cc502b88e42
# Name: samenstelling c
# Quantities:
# Route: INTRAVENEUS
# OrderType: TimedOrder
# Adjust: 11 kg
# AdjustUnit: kg[Weight]
# Frequencies: 1 x/dag
# Time: 20 - 24 uur
# Dose: vloeistof, max 75,5 mL/kg/dosis
# DoseCount: 1 x
# Components:
# 	Name: Samenstelling C
# 	Shape: vloeistof
# 	Quantities: 1 mL
# 	Divisible: 1
# 	Dose: Samenstelling C, 10 - 25 mL/kg/dosis
# 	Solution:
# 	Substances:
#
# 		Name: eiwit
# 		Concentrations: 0,08 g/mL
# 		Dose:
# 		Solution: max 0,05 g/mL
#
# 		Name: natrium
# 		Concentrations: 0,01 mmol/mL
# 		Dose:
# 		Solution: max 0,5 mmol/mL
#
# 		Name: kalium
# 		Concentrations: 0,02 mmol/mL
# 		Dose:
# 		Solution: max 0,5 mmol/mL
# 	Name: NaCl 3%
# 	Shape: vloeistof
# 	Quantities: 1 mL
# 	Divisible: 1
# 	Dose: NaCl 3%, 6 mL/kg/dosis
# 	Solution:
# 	Substances:
#
# 		Name: natrium
# 		Concentrations: 0,5 mmol/mL
# 		Dose:
# 		Solution: max 0,5 mmol/mL
# 	Name: KCl 7,4%
# 	Shape: vloeistof
# 	Quantities: 1 mL
# 	Divisible: 1
# 	Dose: KCl 7,4%, 2 mL/kg/dosis
# 	Solution:
# 	Substances:
#
# 		Name: kalium
# 		Concentrations: 1 mmol/mL
# 		Dose:
# 		Solution: max 0,5 mmol/mL
# 	Name: gluc 10%
# 	Shape: vloeistof
# 	Quantities: 1 mL
# 	Divisible: 1
# 	Dose:
# 	Solution:
# 	Substances:
#
# 		Name: koolhydraat
# 		Concentrations: 0,1 g/mL
# 		Dose:
# 		Solution:

# %% [markdown]
# And a complex TPN setup

# %%
// a complex TPN setup
let tpnComplete =
    { Medication.order with
        Id = "f1adf475-919b-4b7d-9e26-6cc502b88e42"
        Name = "samenstelling c"
        Route = "INTRAVENEUS"
        OrderType = TimedOrder
        Adjust =
            11N
            |> ValueUnit.singleWithUnit Units.Weight.kiloGram
            |> Some
        AdjustUnit = Units.Weight.kiloGram |> Some
        Frequencies =
            1N
            |> ValueUnit.singleWithUnit (Units.Count.times |> Units.per Units.Time.day)
            |> Some
        Time =
            { MinMax.empty with
                Min =
                    20N
                    |> ValueUnit.singleWithUnit Units.Time.hour
                    |> Limit.inclusive
                    |> Some
                Max =
                    24N
                    |> ValueUnit.singleWithUnit Units.Time.hour
                    |> Limit.inclusive
                    |> Some
            }
        Dose =
            { DoseLimit.limit with
                DoseLimitTarget = "vloeistof" |> LimitTarget.FormLimitTarget
                AdjustUnit = Units.Weight.kiloGram |> Some
                QuantityAdjust =
                    { MinMax.empty with
                        Max =
                            (755N / 10N)
                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                            |> Limit.inclusive
                            |> Some
                    }
            }
            |> Some
        DoseCount =
            { MinMax.empty with
                Min = 1N |> ValueUnit.singleWithUnit Units.Count.times |> Limit.inclusive |> Some
                Max = 1N |> ValueUnit.singleWithUnit Units.Count.times |> Limit.inclusive |> Some
            }
        Components =
            [
                // Samenstelling C component
                {
                    Medication.productComponent with
                        Name = "Samenstelling C"
                        Form = "vloeistof"
                        Quantities =
                            1N
                            |> ValueUnit.singleWithUnit Units.Volume.milliLiter
                            |> Some
                        Divisible = Some (1N)
                        Dose =
                            { DoseLimit.limit with
                                DoseLimitTarget = "Samenstelling C" |> LimitTarget.ComponentLimitTarget
                                AdjustUnit = Units.Weight.kiloGram |> Some
                                QuantityAdjust =
                                    { MinMax.empty with
                                        Min =
                                            10N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                        Max =
                                            25N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                    }
                            }
                            |> Some
                        Substances =
                            [
                                {
                                    Medication.substanceItem with
                                        Name = "energie"
                                        Concentrations =
                                            (32N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Energy.kiloCalorie |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "eiwit"
                                        Concentrations =
                                            (8N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Mass.gram |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "eiwit" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 100N)
                                                            |> ValueUnit.singleWithUnit (Units.Mass.gram |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "natrium"
                                        Concentrations =
                                            (1N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "natrium" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 10N)
                                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "kalium"
                                        Concentrations =
                                            (2N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "kalium" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 10N)
                                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "calcium"
                                        Concentrations =
                                            (3N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "fosfaat"
                                        Concentrations =
                                            (2N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "magnesium"
                                        Concentrations =
                                            (1N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "chloor"
                                        Concentrations =
                                            (7N / 100N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                            ]
                }
                // NaCl 3% component
                {
                    Medication.productComponent with
                        Name = "NaCl 3%"
                        Form = "vloeistof"
                        Quantities =
                            1N
                            |> ValueUnit.singleWithUnit Units.Volume.milliLiter
                            |> Some
                        Divisible = Some (1N)
                        Dose =
                            { DoseLimit.limit with
                                DoseLimitTarget = "NaCl 3%" |> LimitTarget.ComponentLimitTarget
                                AdjustUnit = Units.Weight.kiloGram |> Some
                                QuantityAdjust =
                                    { MinMax.empty with
                                        Min =
                                            6N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                        Max =
                                            6N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                    }
                            }
                            |> Some
                        Substances =
                            [
                                {
                                    Medication.substanceItem with
                                        Name = "natrium"
                                        Concentrations =
                                            (5N / 10N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "natrium" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 10N)
                                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "chloor"
                                        Concentrations =
                                            (5N / 10N)
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                            ]
                }
                // KCl 7,4% component
                {
                    Medication.productComponent with
                        Name = "KCl 7,4%"
                        Form = "vloeistof"
                        Quantities =
                            1N
                            |> ValueUnit.singleWithUnit Units.Volume.milliLiter
                            |> Some
                        Divisible = Some (1N)
                        Dose =
                            { DoseLimit.limit with
                                DoseLimitTarget = "KCl 7,4%" |> LimitTarget.ComponentLimitTarget
                                AdjustUnit = Units.Weight.kiloGram |> Some
                                QuantityAdjust =
                                    { MinMax.empty with
                                        Min =
                                            2N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                        Max =
                                            2N
                                            |> ValueUnit.singleWithUnit (Units.Volume.milliLiter |> Units.per Units.Weight.kiloGram)
                                            |> Limit.inclusive
                                            |> Some
                                    }
                            }
                            |> Some
                        Substances =
                            [
                                {
                                    Medication.substanceItem with
                                        Name = "kalium"
                                        Concentrations =
                                            1N
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                        Solution =
                                            { SolutionLimit.limit with
                                                SolutionLimitTarget = "kalium" |> LimitTarget.SubstanceLimitTarget
                                                Concentration =
                                                    { MinMax.empty with
                                                        Max =
                                                            (5N / 10N)
                                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                                            |> Limit.inclusive
                                                            |> Some
                                                    }
                                            }
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "chloor"
                                        Concentrations =
                                            1N
                                            |> ValueUnit.singleWithUnit (Units.Molar.milliMole |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                            ]
                }
                // gluc 10% component
                {
                    Medication.productComponent with
                        Name = "gluc 10%"
                        Form = "vloeistof"
                        Quantities =
                            1N
                            |> ValueUnit.singleWithUnit Units.Volume.milliLiter
                            |> Some
                        Divisible = Some (1N)
                        Substances =
                            [
                                {
                                    Medication.substanceItem with
                                        Name = "energie"
                                        Concentrations =
                                            (4N / 10N)
                                            |> ValueUnit.singleWithUnit (Units.Energy.kiloCalorie |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                                {
                                    Medication.substanceItem with
                                        Name = "koolhydraat"
                                        Concentrations =
                                            (1N / 10N)
                                            |> ValueUnit.singleWithUnit (Units.Mass.gram |> Units.per Units.Volume.milliLiter)
                                            |> Some
                                }
                            ]
                }
            ]
    }

// print out the more complex (complete) tpn
tpnComplete
|> Medication.toString
|> print
# Out:
# Id: f1adf475-919b-4b7d-9e26-6cc502b88e42
# Name: samenstelling c
# Quantities:
# Route: INTRAVENEUS
# OrderType: TimedOrder
# Adjust: 11 kg
# AdjustUnit: kg[Weight]
# Frequencies: 1 x/dag
# Time: 20 - 24 uur
# Dose: vloeistof, max 75,5 mL/kg/dosis
# DoseCount: 1 x
# Components:
# 	Name: Samenstelling C
# 	Shape: vloeistof
# 	Quantities: 1 mL
# 	Divisible: 1
# 	Dose: Samenstelling C, 10 - 25 mL/kg/dosis
# 	Solution:
# 	Substances:
#
# 		Name: energie
# 		Concentrations: 0,32 kCal/mL
# 		Dose:
# 		Solution:
#
# 		Name: eiwit
# 		Concentrations: 0,08 g/mL
# 		Dose:
# 		Solution: max 0,05 g/mL
#
# 		Name: natrium
# 		Concentrations: 0,01 mmol/mL
# 		Dose:
# 		Solution: max 0,5 mmol/mL
#
# 		Name: kalium
# 		Concentrations: 0,02 mmol/mL
# 		Dose:
# 		Solution: max 0,5 mmol/mL
#
# 		Name: calcium
# 		Concentrations: 0,03 mmol/mL
# 		Dose:
# 		Solution:
#
# 		Name: fosfaat
# 		Concentrations: 0,02 mmol/mL
# 		Dose:
# 		Solution:
#
# 		Name: magnesium
# 		Concentrations: 0,01 mmol/mL
# 		Dose:
# 		Solution:
#
# 		Name: chloor
# 		Concentrations: 0,07 mmol/mL
# 		Dose:
# 		Solution:
# 	Name: NaCl 3%
# 	Shape: vloeistof
# 	Quantities: 1 mL
# 	Divisible: 1
# 	Dose: NaCl 3%, 6 mL/kg/dosis
# 	Solution:
# 	Substances:
#
# 		Name: natrium
# 		Concentrations: 0,5 mmol/mL
# 		Dose:
# 		Solution: max 0,5 mmol/mL
#
# 		Name: chloor
# 		Concentrations: 0,5 mmol/mL
# 		Dose:
# 		Solution:
# 	Name: KCl 7,4%
# 	Shape: vloeistof
# 	Quantities: 1 mL
# 	Divisible: 1
# 	Dose: KCl 7,4%, 2 mL/kg/dosis
# 	Solution:
# 	Substances:
#
# 		Name: kalium
# 		Concentrations: 1 mmol/mL
# 		Dose:
# 		Solution: max 0,5 mmol/mL
#
# 		Name: chloor
# 		Concentrations: 1 mmol/mL
# 		Dose:
# 		Solution:
# 	Name: gluc 10%
# 	Shape: vloeistof
# 	Quantities: 1 mL
# 	Divisible: 1
# 	Dose:
# 	Solution:
# 	Substances:
#
# 		Name: energie
# 		Concentrations: 0,4 kCal/mL
# 		Dose:
# 		Solution:
#
# 		Name: koolhydraat
# 		Concentrations: 0,1 g/mL
# 		Dose:
# 		Solution:

# %% [markdown]
# And we can run a specific scenario with setting protein to 50%, potassium to 10%, sodium to 5% and glucose to 100%

# %%
tpnSimple
|> run 50 10 5 100 
|> ignore
# Out:
# 1 - NAME                                 2 - VARIABLE  3 - VALUE                            4 - CONSTRAINTS
# --------------------------------------------------------------------------------------------------------------------------------
#                                          sch_frq       1 x/dag                              1 x/dag
#                                          sch_tme       20 uur..24 uur                       20 uur..24 uur
# samenstelling c                          ord_qty       <0 ..>                               <0 ..>
# samenstelling c                          orb_qty       0,1 mL..0,1 mL..>                    0,1 mL..0,1 mL..>
# samenstelling c                          ord_cnt       <0 x..>                              <0 x..>
# samenstelling c                          dos_cnt       1 x                                  1 x
# samenstelling c                          dos_qty       0,1 mL..0,1 mL..>                    0,1 mL..0,1 mL..>
# samenstelling c                          dos_ptm       <0 mL/dag..>                         <0 mL/dag..>
# samenstelling c                          dos_rte       0,1;0,2;0,3 mL/uur .. 980;990;1 000  0,1;0,2;0,3 mL/uur .. 980;990;1 000
#                                                        mL/uur                               mL/uur
# samenstelling c                          dos_tot       <0 ..>                               <0 ..>
# samenstelling c                          dos_qty_adj   <0 mL/kg..75,5 mL/kg                 <0 mL/kg..75,5 mL/kg
# samenstelling c                          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c                          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c                          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          cmp_qty       <0 ..>                               1 mL
# samenstelling c.Samenstelling C          orb_qty       1 mL..1 mL..>                        1 mL..1 mL..>
# samenstelling c.Samenstelling C          orb_cnt       <0 x..>                              <0 x..>
# samenstelling c.Samenstelling C          orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          ord_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          ord_cnt       <0 x..>                              <0 x..>
# samenstelling c.Samenstelling C          dos_qty       <0 ..>                               <0 mL..>
# samenstelling c.Samenstelling C          dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_qty_adj   <0 ..>                               10 mL/kg..25 mL/kg
# samenstelling c.Samenstelling C          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_cnc       0,08 g/mL                            0,08 g/mL
# samenstelling c.Samenstelling C.eiwit    orb_cnc       <0 g/mL..0,05 g/mL                   <0 g/mL..0,05 g/mL
# samenstelling c.Samenstelling C.eiwit    dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_cnc       0,01 mmol/mL                         0,01 mmol/mL
# samenstelling c.Samenstelling C.natrium  orb_cnc       <0 mmol/mL..0,5 mmol/mL              <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.natrium  dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_cnc       0,02 mmol/mL                         0,02 mmol/mL
# samenstelling c.Samenstelling C.kalium   orb_cnc       <0 mmol/mL..0,5 mmol/mL              <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.kalium   dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  cmp_qty       <0 ..>                               1 mL
# samenstelling c.NaCl 3%                  orb_qty       1 mL..1 mL..>                        1 mL..1 mL..>
# samenstelling c.NaCl 3%                  orb_cnt       <0 x..>                              <0 x..>
# samenstelling c.NaCl 3%                  orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  ord_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  ord_cnt       <0 x..>                              <0 x..>
# samenstelling c.NaCl 3%                  dos_qty       <0 ..>                               <0 mL..>
# samenstelling c.NaCl 3%                  dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_rte       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_tot       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_qty_adj   <0 ..>                               6 mL/kg
# samenstelling c.NaCl 3%                  dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          orb_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_cnc       0,5 mmol/mL                          0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          orb_cnc       <0 mmol/mL..0,5 mmol/mL              <0 mmol/mL..0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          dos_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 cmp_qty       <0 ..>                               1 mL
# samenstelling c.KCl 7,4%                 orb_qty       1 mL..1 mL..>                        1 mL..1 mL..>
# samenstelling c.KCl 7,4%                 orb_cnt       <0 x..>                              <0 x..>
# samenstelling c.KCl 7,4%                 orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 ord_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 ord_cnt       <0 x..>                              <0 x..>
# samenstelling c.KCl 7,4%                 dos_qty       <0 ..>                               <0 mL..>
# samenstelling c.KCl 7,4%                 dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_qty_adj   <0 ..>                               2 mL/kg
# samenstelling c.KCl 7,4%                 dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          orb_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_cnc       1 mmol/mL                            1 mmol/mL
# samenstelling c.KCl 7,4%.kalium          orb_cnc       <0 mmol/mL..0,5 mmol/mL              <0 mmol/mL..0,5 mmol/mL
# samenstelling c.KCl 7,4%.kalium          dos_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 cmp_qty       <0 ..>                               1 mL
# samenstelling c.gluc 10%                 orb_qty       1 mL..1 mL..>                        1 mL..1 mL..>
# samenstelling c.gluc 10%                 orb_cnt       <0 x..>                              <0 x..>
# samenstelling c.gluc 10%                 orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 ord_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 ord_cnt       <0 x..>                              <0 x..>
# samenstelling c.gluc 10%                 dos_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_rte       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_tot       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     orb_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_cnc       0,1 g/mL                             0,1 g/mL
# samenstelling c.gluc 10%.koolhydraat     orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot_adj   <0 ..>                               <0 ..>
#                                          adj_qty       11 kg                                11 kg
#
# 1 - NAME                                 2 - VARIABLE  3 - VALUE                                 4 - CONSTRAINTS
# -------------------------------------------------------------------------------------------------------------------------------------
#                                          sch_frq       1 x/dag                                   1 x/dag
#                                          sch_tme       20 uur..24 uur                            20 uur..24 uur
# samenstelling c                          ord_qty       <0 mL..>                                  <0 ..>
# samenstelling c                          orb_qty       4 mL..1 mL..830 mL                        0,1 mL..0,1 mL..>
# samenstelling c                          ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c                          dos_cnt       1 x                                       1 x
# samenstelling c                          dos_qty       4 mL..1 mL..830 mL                        0,1 mL..0,1 mL..>
# samenstelling c                          dos_ptm       4 mL/dag..1 mL/dag..830 mL/dag            <0 mL/dag..>
# samenstelling c                          dos_rte       0,2;0,3;0,4 mL/uur .. 39;40;41 mL/uur     0,1;0,2;0,3 mL/uur .. 980;990;1 000
#                                                                                                  mL/uur
# samenstelling c                          dos_tot       <0 ..>                                    <0 ..>
# samenstelling c                          dos_qty_adj   0,36 mL/kg..75,5 mL/kg                    <0 mL/kg..75,5 mL/kg
# samenstelling c                          dos_ptm_adj   0,36 mL/kg/dag..75,5 mL/kg/dag            <0 ..>
# samenstelling c                          dos_rte_adj   0,02 mL/kg/uur..3,73 mL/kg/uur            <0 ..>
# samenstelling c                          dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          cmp_qty       <0 mL..>                                  1 mL
# samenstelling c.Samenstelling C          orb_qty       1 mL..1 mL..518 mL                        1 mL..1 mL..>
# samenstelling c.Samenstelling C          orb_cnt       <0 x..>                                   <0 x..>
# samenstelling c.Samenstelling C          orb_cnc       0 x..130 x                                <0 ..>
# samenstelling c.Samenstelling C          ord_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c.Samenstelling C          dos_qty       1 mL..1 mL..518 mL                        <0 mL..>
# samenstelling c.Samenstelling C          dos_ptm       1 mL/dag..1 mL/dag..518 mL/dag            <0 ..>
# samenstelling c.Samenstelling C          dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_qty_adj   0,09 mL/kg..47,1 mL/kg                    10 mL/kg..25 mL/kg
# samenstelling c.Samenstelling C          dos_ptm_adj   0,09 mL/kg/dag..47,1 mL/kg/dag            <0 ..>
# samenstelling c.Samenstelling C          dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    orb_qty       0,08 g..0,08 g..41,4 g                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_cnc       0,08 g/mL                                 0,08 g/mL
# samenstelling c.Samenstelling C.eiwit    orb_cnc       0 g/mL..0,05 g/mL                         <0 g/mL..0,05 g/mL
# samenstelling c.Samenstelling C.eiwit    dos_qty       0,08 g..0,08 g..41,4 g                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm       0,08 g/dag..0,08 g/dag..41,4 g/dag        <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_qty_adj   0,01 g/kg..3,77 g/kg                      <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm_adj   0,01 g/kg/dag..3,77 g/kg/dag              <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  orb_qty       0,01 mmol..0,01 mmol..5,18 mmol           <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_cnc       0,01 mmol/mL                              0,01 mmol/mL
# samenstelling c.Samenstelling C.natrium  orb_cnc       0 mmol/mL..0,5 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.natrium  dos_qty       0,01 mmol..0,01 mmol..5,18 mmol           <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm       0,01 mmol/dag..0,01 mmol/dag..5,18        <0 ..>
#                                                        mmol/dag
# samenstelling c.Samenstelling C.natrium  dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_qty_adj   0 mmol/kg..0,47 mmol/kg                   <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm_adj   0 mmol/kg/dag..0,47 mmol/kg/dag           <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   orb_qty       0,02 mmol..0,02 mmol..10,4 mmol           <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_cnc       0,02 mmol/mL                              0,02 mmol/mL
# samenstelling c.Samenstelling C.kalium   orb_cnc       0 mmol/mL..0,5 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.kalium   dos_qty       0,02 mmol..0,02 mmol..10,4 mmol           <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm       0,02 mmol/dag..0,02 mmol/dag..10,4        <0 ..>
#                                                        mmol/dag
# samenstelling c.Samenstelling C.kalium   dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_qty_adj   0 mmol/kg..0,94 mmol/kg                   <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm_adj   0 mmol/kg/dag..0,94 mmol/kg/dag           <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%                  cmp_qty       <0 mL..>                                  1 mL
# samenstelling c.NaCl 3%                  orb_qty       1 mL..1 mL..827 mL                        1 mL..1 mL..>
# samenstelling c.NaCl 3%                  orb_cnt       <0 x..>                                   <0 x..>
# samenstelling c.NaCl 3%                  orb_cnc       0 x..207 x                                <0 ..>
# samenstelling c.NaCl 3%                  ord_qty       <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%                  ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c.NaCl 3%                  dos_qty       1 mL..1 mL..827 mL                        <0 mL..>
# samenstelling c.NaCl 3%                  dos_ptm       1 mL/dag..1 mL/dag..827 mL/dag            <0 ..>
# samenstelling c.NaCl 3%                  dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%                  dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%                  dos_qty_adj   0,09 mL/kg..75,2 mL/kg                    6 mL/kg
# samenstelling c.NaCl 3%                  dos_ptm_adj   0,09 mL/kg/dag..75,2 mL/kg/dag            <0 ..>
# samenstelling c.NaCl 3%                  dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%                  dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%.natrium          orb_qty       0,5 mmol..0,5 mmol..414 mmol              <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_cnc       0,5 mmol/mL                               0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          orb_cnc       0 mmol/mL..0,5 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          dos_qty       0,5 mmol..0,5 mmol..414 mmol              <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm       0,5 mmol/dag..0,5 mmol/dag..414 mmol/dag  <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_qty_adj   0,05 mmol/kg..37,6 mmol/kg                <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm_adj   0,05 mmol/kg/dag..37,6 mmol/kg/dag        <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%                 cmp_qty       <0 mL..>                                  1 mL
# samenstelling c.KCl 7,4%                 orb_qty       1 mL..1 mL..415 mL                        1 mL..1 mL..>
# samenstelling c.KCl 7,4%                 orb_cnt       <0 x..>                                   <0 x..>
# samenstelling c.KCl 7,4%                 orb_cnc       0 x..104 x                                <0 ..>
# samenstelling c.KCl 7,4%                 ord_qty       <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%                 ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c.KCl 7,4%                 dos_qty       1 mL..1 mL..415 mL                        <0 mL..>
# samenstelling c.KCl 7,4%                 dos_ptm       1 mL/dag..1 mL/dag..415 mL/dag            <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%                 dos_qty_adj   0,09 mL/kg..37,7 mL/kg                    2 mL/kg
# samenstelling c.KCl 7,4%                 dos_ptm_adj   0,09 mL/kg/dag..37,7 mL/kg/dag            <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%.kalium          orb_qty       1 mmol..1 mmol..415 mmol                  <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_cnc       1 mmol/mL                                 1 mmol/mL
# samenstelling c.KCl 7,4%.kalium          orb_cnc       0 mmol/mL..0,5 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.KCl 7,4%.kalium          dos_qty       1 mmol..1 mmol..415 mmol                  <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm       1 mmol/dag..1 mmol/dag..415 mmol/dag      <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_qty_adj   0,09 mmol/kg..37,7 mmol/kg                <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm_adj   0,09 mmol/kg/dag..37,7 mmol/kg/dag        <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%                 cmp_qty       <0 mL..>                                  1 mL
# samenstelling c.gluc 10%                 orb_qty       1 mL..1 mL..827 mL                        1 mL..1 mL..>
# samenstelling c.gluc 10%                 orb_cnt       <0 x..>                                   <0 x..>
# samenstelling c.gluc 10%                 orb_cnc       0 x..207 x                                <0 ..>
# samenstelling c.gluc 10%                 ord_qty       <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%                 ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c.gluc 10%                 dos_qty       1 mL..1 mL..827 mL                        <0 ..>
# samenstelling c.gluc 10%                 dos_ptm       1 mL/dag..1 mL/dag..827 mL/dag            <0 ..>
# samenstelling c.gluc 10%                 dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%                 dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%                 dos_qty_adj   0,09 mL/kg..75,2 mL/kg                    <0 ..>
# samenstelling c.gluc 10%                 dos_ptm_adj   0,09 mL/kg/dag..75,2 mL/kg/dag            <0 ..>
# samenstelling c.gluc 10%                 dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%                 dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%.koolhydraat     orb_qty       0,1 g..0,1 g..82,7 g                      <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_cnc       0,1 g/mL                                  0,1 g/mL
# samenstelling c.gluc 10%.koolhydraat     orb_cnc       0 g/mL..20,7 g/mL                         <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty       0,1 g..0,1 g..82,7 g                      <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm       0,1 g/dag..0,1 g/dag..82,7 g/dag          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty_adj   0,01 g/kg..7,52 g/kg                      <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm_adj   0,01 g/kg/dag..7,52 g/kg/dag              <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot_adj   <0 ..>                                    <0 ..>
#                                          adj_qty       11 kg                                     11 kg
#
# === Apply PropChange Samenstelling C ===
# 1 - NAME                                 2 - VARIABLE  3 - VALUE                                 4 - CONSTRAINTS
# -------------------------------------------------------------------------------------------------------------------------------------
#                                          sch_frq       1 x/dag                                   1 x/dag
#                                          sch_tme       20 uur..24 uur                            20 uur..24 uur
# samenstelling c                          ord_qty       <0 mL..>                                  <0 ..>
# samenstelling c                          orb_qty       415 mL..1 mL..830 mL                      0,1 mL..0,1 mL..>
# samenstelling c                          ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c                          dos_cnt       1 x                                       1 x
# samenstelling c                          dos_qty       415 mL..1 mL..830 mL                      0,1 mL..0,1 mL..>
# samenstelling c                          dos_ptm       415 mL/dag..1 mL/dag..830 mL/dag          <0 mL/dag..>
# samenstelling c                          dos_rte       18;19;20 mL/uur .. 39;40;41 mL/uur        0,1;0,2;0,3 mL/uur .. 980;990;1 000
#                                                                                                  mL/uur
# samenstelling c                          dos_tot       <0 ..>                                    <0 ..>
# samenstelling c                          dos_qty_adj   37,7 mL/kg..75,5 mL/kg                    <0 mL/kg..75,5 mL/kg
# samenstelling c                          dos_ptm_adj   37,7 mL/kg/dag..75,5 mL/kg/dag            <0 ..>
# samenstelling c                          dos_rte_adj   1,64 mL/kg/uur..3,73 mL/kg/uur            <0 ..>
# samenstelling c                          dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          cmp_qty       <0 mL..>                                  1 mL
# samenstelling c.Samenstelling C          orb_qty       259 mL                                    1 mL..1 mL..>
# samenstelling c.Samenstelling C          orb_cnt       <0 x..>                                   <0 x..>
# samenstelling c.Samenstelling C          orb_cnc       0,31 x..0,62 x                            <0 ..>
# samenstelling c.Samenstelling C          ord_qty       <0 mL..>                                  <0 ..>
# samenstelling c.Samenstelling C          ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c.Samenstelling C          dos_qty       259 mL                                    <0 mL..>
# samenstelling c.Samenstelling C          dos_ptm       259 mL/dag                                <0 ..>
# samenstelling c.Samenstelling C          dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_qty_adj   23,5 mL/kg                                10 mL/kg..25 mL/kg
# samenstelling c.Samenstelling C          dos_ptm_adj   23,5 mL/kg/dag                            <0 ..>
# samenstelling c.Samenstelling C          dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_qty       <0 g..>                                   <0 ..>
# samenstelling c.Samenstelling C.eiwit    orb_qty       20,7 g                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_cnc       0,08 g/mL                                 0,08 g/mL
# samenstelling c.Samenstelling C.eiwit    orb_cnc       0,03 g/mL..0,05 g/mL                      <0 g/mL..0,05 g/mL
# samenstelling c.Samenstelling C.eiwit    dos_qty       20,7 g                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm       20,7 g/dag                                <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_qty_adj   1,88 g/kg                                 <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm_adj   1,88 g/kg/dag                             <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_qty       <0 mmol..>                                <0 ..>
# samenstelling c.Samenstelling C.natrium  orb_qty       2,59 mmol                                 <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_cnc       0,01 mmol/mL                              0,01 mmol/mL
# samenstelling c.Samenstelling C.natrium  orb_cnc       0 mmol/mL..0,01 mmol/mL                   <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.natrium  dos_qty       2,59 mmol                                 <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm       2,59 mmol/dag                             <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_qty_adj   0,24 mmol/kg                              <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm_adj   0,24 mmol/kg/dag                          <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_qty       <0 mmol..>                                <0 ..>
# samenstelling c.Samenstelling C.kalium   orb_qty       5,18 mmol                                 <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_cnc       0,02 mmol/mL                              0,02 mmol/mL
# samenstelling c.Samenstelling C.kalium   orb_cnc       0,01 mmol/mL..0,01 mmol/mL                <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.kalium   dos_qty       5,18 mmol                                 <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm       5,18 mmol/dag                             <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_qty_adj   0,47 mmol/kg                              <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm_adj   0,47 mmol/kg/dag                          <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.NaCl 3%                  cmp_qty       <0 mL..>                                  1 mL
# samenstelling c.NaCl 3%                  orb_qty       1 mL..1 mL..569 mL                        1 mL..1 mL..>
# ...
# samenstelling c.Samenstelling C          cmp_qty       <0 mL..>                        1 mL
# samenstelling c.Samenstelling C          orb_qty       259 mL                          1 mL..1 mL..>
# samenstelling c.Samenstelling C          orb_cnt       <0 x..>                         <0 x..>
# samenstelling c.Samenstelling C          orb_cnc       0,31 x                          <0 ..>
# samenstelling c.Samenstelling C          ord_qty       <0 mL..>                        <0 ..>
# samenstelling c.Samenstelling C          ord_cnt       <0 x..>                         <0 x..>
# samenstelling c.Samenstelling C          dos_qty       259 mL                          <0 mL..>
# samenstelling c.Samenstelling C          dos_ptm       259 mL/dag                      <0 ..>
# samenstelling c.Samenstelling C          dos_rte       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C          dos_tot       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C          dos_qty_adj   23,5 mL/kg                      10 mL/kg..25 mL/kg
# samenstelling c.Samenstelling C          dos_ptm_adj   23,5 mL/kg/dag                  <0 ..>
# samenstelling c.Samenstelling C          dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C          dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_qty       <0 g..>                         <0 ..>
# samenstelling c.Samenstelling C.eiwit    orb_qty       20,7 g                          <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_cnc       0,08 g/mL                       0,08 g/mL
# samenstelling c.Samenstelling C.eiwit    orb_cnc       0,03 g/mL                       <0 g/mL..0,05 g/mL
# samenstelling c.Samenstelling C.eiwit    dos_qty       20,7 g                          <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm       20,7 g/dag                      <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_qty_adj   1,88 g/kg                       <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm_adj   1,88 g/kg/dag                   <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.Samenstelling C.natrium  orb_qty       2,59 mmol                       <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_cnc       0,01 mmol/mL                    0,01 mmol/mL
# samenstelling c.Samenstelling C.natrium  orb_cnc       0 mmol/mL                       <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.natrium  dos_qty       2,59 mmol                       <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm       2,59 mmol/dag                   <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_qty_adj   0,24 mmol/kg                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm_adj   0,24 mmol/kg/dag                <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.Samenstelling C.kalium   orb_qty       5,18 mmol                       <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_cnc       0,02 mmol/mL                    0,02 mmol/mL
# samenstelling c.Samenstelling C.kalium   orb_cnc       0,01 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.kalium   dos_qty       5,18 mmol                       <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm       5,18 mmol/dag                   <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_qty_adj   0,47 mmol/kg                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm_adj   0,47 mmol/kg/dag                <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%                  cmp_qty       <0 mL..>                        1 mL
# samenstelling c.NaCl 3%                  orb_qty       27 mL                           1 mL..1 mL..>
# samenstelling c.NaCl 3%                  orb_cnt       <0 x..>                         <0 x..>
# samenstelling c.NaCl 3%                  orb_cnc       0,03 x                          <0 ..>
# samenstelling c.NaCl 3%                  ord_qty       <0 mL..>                        <0 ..>
# samenstelling c.NaCl 3%                  ord_cnt       <0 x..>                         <0 x..>
# samenstelling c.NaCl 3%                  dos_qty       27 mL                           <0 mL..>
# samenstelling c.NaCl 3%                  dos_ptm       27 mL/dag                       <0 ..>
# samenstelling c.NaCl 3%                  dos_rte       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%                  dos_tot       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%                  dos_qty_adj   2,45 mL/kg                      6 mL/kg
# samenstelling c.NaCl 3%                  dos_ptm_adj   2,45 mL/kg/dag                  <0 ..>
# samenstelling c.NaCl 3%                  dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%                  dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.NaCl 3%.natrium          orb_qty       13,5 mmol                       <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_cnc       0,5 mmol/mL                     0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          orb_cnc       0,02 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          dos_qty       13,5 mmol                       <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm       13,5 mmol/dag                   <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_qty_adj   1,23 mmol/kg                    <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm_adj   1,23 mmol/kg/dag                <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%                 cmp_qty       <0 mL..>                        1 mL
# samenstelling c.KCl 7,4%                 orb_qty       42 mL                           1 mL..1 mL..>
# samenstelling c.KCl 7,4%                 orb_cnt       <0 x..>                         <0 x..>
# samenstelling c.KCl 7,4%                 orb_cnc       0,05 x                          <0 ..>
# samenstelling c.KCl 7,4%                 ord_qty       <0 mL..>                        <0 ..>
# samenstelling c.KCl 7,4%                 ord_cnt       <0 x..>                         <0 x..>
# samenstelling c.KCl 7,4%                 dos_qty       42 mL                           <0 mL..>
# samenstelling c.KCl 7,4%                 dos_ptm       42 mL/dag                       <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%                 dos_qty_adj   3,82 mL/kg                      2 mL/kg
# samenstelling c.KCl 7,4%                 dos_ptm_adj   3,82 mL/kg/dag                  <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.KCl 7,4%.kalium          orb_qty       42 mmol                         <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_cnc       1 mmol/mL                       1 mmol/mL
# samenstelling c.KCl 7,4%.kalium          orb_cnc       0,05 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.KCl 7,4%.kalium          dos_qty       42 mmol                         <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm       42 mmol/dag                     <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_qty_adj   3,82 mmol/kg                    <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm_adj   3,82 mmol/kg/dag                <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%                 cmp_qty       <0 mL..>                        1 mL
# samenstelling c.gluc 10%                 orb_qty       502 mL                          1 mL..1 mL..>
# samenstelling c.gluc 10%                 orb_cnt       <0 x..>                         <0 x..>
# samenstelling c.gluc 10%                 orb_cnc       0,61 x                          <0 ..>
# samenstelling c.gluc 10%                 ord_qty       <0 mL..>                        <0 ..>
# samenstelling c.gluc 10%                 ord_cnt       <0 x..>                         <0 x..>
# samenstelling c.gluc 10%                 dos_qty       502 mL                          <0 ..>
# samenstelling c.gluc 10%                 dos_ptm       502 mL/dag                      <0 ..>
# samenstelling c.gluc 10%                 dos_rte       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%                 dos_tot       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%                 dos_qty_adj   45,6 mL/kg                      <0 ..>
# samenstelling c.gluc 10%                 dos_ptm_adj   45,6 mL/kg/dag                  <0 ..>
# samenstelling c.gluc 10%                 dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%                 dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_qty       <0 g..>                         <0 ..>
# samenstelling c.gluc 10%.koolhydraat     orb_qty       50,2 g                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_cnc       0,1 g/mL                        0,1 g/mL
# samenstelling c.gluc 10%.koolhydraat     orb_cnc       0,06 g/mL                       <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty       50,2 g                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm       50,2 g/dag                      <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty_adj   4,56 g/kg                       <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm_adj   4,56 g/kg/dag                   <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot_adj   <0 ..>                          <0 ..>
#                                          adj_qty       11 kg                           11 kg

# %% [markdown]
# The same for a more complex (complete) TPN medication order

# %%
tpnComplete
|> run 70 10 5 1
|> ignore
# Out:
# 1 - NAME                                 2 - VARIABLE  3 - VALUE                            4 - CONSTRAINTS
# --------------------------------------------------------------------------------------------------------------------------------
#                                          sch_frq       1 x/dag                              1 x/dag
#                                          sch_tme       20 uur..24 uur                       20 uur..24 uur
# samenstelling c                          ord_qty       <0 ..>                               <0 ..>
# samenstelling c                          orb_qty       0,1 mL..0,1 mL..>                    0,1 mL..0,1 mL..>
# samenstelling c                          ord_cnt       <0 x..>                              <0 x..>
# samenstelling c                          dos_cnt       1 x                                  1 x
# samenstelling c                          dos_qty       0,1 mL..0,1 mL..>                    0,1 mL..0,1 mL..>
# samenstelling c                          dos_ptm       <0 mL/dag..>                         <0 mL/dag..>
# samenstelling c                          dos_rte       0,1;0,2;0,3 mL/uur .. 980;990;1 000  0,1;0,2;0,3 mL/uur .. 980;990;1 000
#                                                        mL/uur                               mL/uur
# samenstelling c                          dos_tot       <0 ..>                               <0 ..>
# samenstelling c                          dos_qty_adj   <0 mL/kg..75,5 mL/kg                 <0 mL/kg..75,5 mL/kg
# samenstelling c                          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c                          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c                          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          cmp_qty       <0 ..>                               1 mL
# samenstelling c.Samenstelling C          orb_qty       1 mL..1 mL..>                        1 mL..1 mL..>
# samenstelling c.Samenstelling C          orb_cnt       <0 x..>                              <0 x..>
# samenstelling c.Samenstelling C          orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          ord_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          ord_cnt       <0 x..>                              <0 x..>
# samenstelling c.Samenstelling C          dos_qty       <0 ..>                               <0 mL..>
# samenstelling c.Samenstelling C          dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_qty_adj   <0 ..>                               10 mL/kg..25 mL/kg
# samenstelling c.Samenstelling C          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  cmp_cnc       0,32 kCal/mL                         0,32 kCal/mL
# samenstelling c.Samenstelling C.energie  orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.energie  dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_cnc       0,08 g/mL                            0,08 g/mL
# samenstelling c.Samenstelling C.eiwit    orb_cnc       <0 g/mL..0,05 g/mL                   <0 g/mL..0,05 g/mL
# samenstelling c.Samenstelling C.eiwit    dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_cnc       0,01 mmol/mL                         0,01 mmol/mL
# samenstelling c.Samenstelling C.natrium  orb_cnc       <0 mmol/mL..0,5 mmol/mL              <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.natrium  dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_cnc       0,02 mmol/mL                         0,02 mmol/mL
# samenstelling c.Samenstelling C.kalium   orb_cnc       <0 mmol/mL..0,5 mmol/mL              <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.kalium   dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  cmp_cnc       0,03 mmol/mL                         0,03 mmol/mL
# samenstelling c.Samenstelling C.calcium  orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  cmp_cnc       0,02 mmol/mL                         0,02 mmol/mL
# samenstelling c.Samenstelling C.fosfaat  orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling            cmp_qty       <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            orb_qty       <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            cmp_cnc       0,01 mmol/mL                         0,01 mmol/mL
# C.magnesium
# samenstelling c.Samenstelling            orb_cnc       <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            dos_qty       <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            dos_ptm       <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            dos_rte       <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            dos_tot       <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            dos_qty_adj   <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            dos_ptm_adj   <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            dos_rte_adj   <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            dos_tot_adj   <0 ..>                               <0 ..>
# C.magnesium
# samenstelling c.Samenstelling C.chloor   cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   orb_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   cmp_cnc       0,07 mmol/mL                         0,07 mmol/mL
# samenstelling c.Samenstelling C.chloor   orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_qty       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_rte       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_tot       <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  cmp_qty       <0 ..>                               1 mL
# samenstelling c.NaCl 3%                  orb_qty       1 mL..1 mL..>                        1 mL..1 mL..>
# samenstelling c.NaCl 3%                  orb_cnt       <0 x..>                              <0 x..>
# samenstelling c.NaCl 3%                  orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  ord_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  ord_cnt       <0 x..>                              <0 x..>
# samenstelling c.NaCl 3%                  dos_qty       <0 ..>                               <0 mL..>
# samenstelling c.NaCl 3%                  dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_rte       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_tot       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_qty_adj   <0 ..>                               6 mL/kg
# samenstelling c.NaCl 3%                  dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%                  dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          orb_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_cnc       0,5 mmol/mL                          0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          orb_cnc       <0 mmol/mL..0,5 mmol/mL              <0 mmol/mL..0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          dos_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           orb_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           cmp_cnc       0,5 mmol/mL                          0,5 mmol/mL
# samenstelling c.NaCl 3%.chloor           orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_qty       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_rte       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_tot       <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 cmp_qty       <0 ..>                               1 mL
# samenstelling c.KCl 7,4%                 orb_qty       1 mL..1 mL..>                        1 mL..1 mL..>
# samenstelling c.KCl 7,4%                 orb_cnt       <0 x..>                              <0 x..>
# samenstelling c.KCl 7,4%                 orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 ord_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 ord_cnt       <0 x..>                              <0 x..>
# samenstelling c.KCl 7,4%                 dos_qty       <0 ..>                               <0 mL..>
# samenstelling c.KCl 7,4%                 dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_qty_adj   <0 ..>                               2 mL/kg
# samenstelling c.KCl 7,4%                 dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          orb_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_cnc       1 mmol/mL                            1 mmol/mL
# samenstelling c.KCl 7,4%.kalium          orb_cnc       <0 mmol/mL..0,5 mmol/mL              <0 mmol/mL..0,5 mmol/mL
# samenstelling c.KCl 7,4%.kalium          dos_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          orb_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          cmp_cnc       1 mmol/mL                            1 mmol/mL
# samenstelling c.KCl 7,4%.chloor          orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_qty       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_rte       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_tot       <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 cmp_qty       <0 ..>                               1 mL
# samenstelling c.gluc 10%                 orb_qty       1 mL..1 mL..>                        1 mL..1 mL..>
# samenstelling c.gluc 10%                 orb_cnt       <0 x..>                              <0 x..>
# samenstelling c.gluc 10%                 orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 ord_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 ord_cnt       <0 x..>                              <0 x..>
# samenstelling c.gluc 10%                 dos_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_rte       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_tot       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%                 dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         orb_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         cmp_cnc       0,4 kCal/mL                          0,4 kCal/mL
# samenstelling c.gluc 10%.energie         orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         dos_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         dos_rte       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         dos_tot       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.energie         dos_tot_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     orb_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_cnc       0,1 g/mL                             0,1 g/mL
# samenstelling c.gluc 10%.koolhydraat     orb_cnc       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot       <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte_adj   <0 ..>                               <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot_adj   <0 ..>                               <0 ..>
#                                          adj_qty       11 kg                                11 kg
#
# 1 - NAME                                 2 - VARIABLE  3 - VALUE                                 4 - CONSTRAINTS
# -------------------------------------------------------------------------------------------------------------------------------------
#                                          sch_frq       1 x/dag                                   1 x/dag
#                                          sch_tme       20 uur..24 uur                            20 uur..24 uur
# samenstelling c                          ord_qty       <0 mL..>                                  <0 ..>
# samenstelling c                          orb_qty       4 mL..1 mL..830 mL                        0,1 mL..0,1 mL..>
# samenstelling c                          ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c                          dos_cnt       1 x                                       1 x
# samenstelling c                          dos_qty       4 mL..1 mL..830 mL                        0,1 mL..0,1 mL..>
# samenstelling c                          dos_ptm       4 mL/dag..1 mL/dag..830 mL/dag            <0 mL/dag..>
# samenstelling c                          dos_rte       0,2;0,3;0,4 mL/uur .. 39;40;41 mL/uur     0,1;0,2;0,3 mL/uur .. 980;990;1 000
#                                                                                                  mL/uur
# samenstelling c                          dos_tot       <0 ..>                                    <0 ..>
# samenstelling c                          dos_qty_adj   0,36 mL/kg..75,5 mL/kg                    <0 mL/kg..75,5 mL/kg
# samenstelling c                          dos_ptm_adj   0,36 mL/kg/dag..75,5 mL/kg/dag            <0 ..>
# samenstelling c                          dos_rte_adj   0,02 mL/kg/uur..3,73 mL/kg/uur            <0 ..>
# samenstelling c                          dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          cmp_qty       <0 mL..>                                  1 mL
# samenstelling c.Samenstelling C          orb_qty       1 mL..1 mL..518 mL                        1 mL..1 mL..>
# samenstelling c.Samenstelling C          orb_cnt       <0 x..>                                   <0 x..>
# samenstelling c.Samenstelling C          orb_cnc       0 x..130 x                                <0 ..>
# samenstelling c.Samenstelling C          ord_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          ord_cnt       <0 x..>                                   <0 x..>
# samenstelling c.Samenstelling C          dos_qty       1 mL..1 mL..518 mL                        <0 mL..>
# samenstelling c.Samenstelling C          dos_ptm       1 mL/dag..1 mL/dag..518 mL/dag            <0 ..>
# samenstelling c.Samenstelling C          dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_qty_adj   0,09 mL/kg..47,1 mL/kg                    10 mL/kg..25 mL/kg
# samenstelling c.Samenstelling C          dos_ptm_adj   0,09 mL/kg/dag..47,1 mL/kg/dag            <0 ..>
# samenstelling c.Samenstelling C          dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C          dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.energie  cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.energie  orb_qty       0,32 kCal..0,32 kCal..166 kCal            <0 ..>
# samenstelling c.Samenstelling C.energie  cmp_cnc       0,32 kCal/mL                              0,32 kCal/mL
# samenstelling c.Samenstelling C.energie  orb_cnc       0 kCal/mL..41,4 kCal/mL                   <0 ..>
# samenstelling c.Samenstelling C.energie  dos_qty       0,32 kCal..0,32 kCal..166 kCal            <0 ..>
# samenstelling c.Samenstelling C.energie  dos_ptm       0,32 kCal/dag..0,32 kCal/dag..166         <0 ..>
#                                                        kCal/dag
# samenstelling c.Samenstelling C.energie  dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.energie  dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.energie  dos_qty_adj   0,03 kCal/kg..15,1 kCal/kg                <0 ..>
# samenstelling c.Samenstelling C.energie  dos_ptm_adj   0,03 kCal/kg/dag..15,1 kCal/kg/dag        <0 ..>
# samenstelling c.Samenstelling C.energie  dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.energie  dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    orb_qty       0,08 g..0,08 g..41,4 g                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    cmp_cnc       0,08 g/mL                                 0,08 g/mL
# samenstelling c.Samenstelling C.eiwit    orb_cnc       0 g/mL..0,05 g/mL                         <0 g/mL..0,05 g/mL
# samenstelling c.Samenstelling C.eiwit    dos_qty       0,08 g..0,08 g..41,4 g                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm       0,08 g/dag..0,08 g/dag..41,4 g/dag        <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_qty_adj   0,01 g/kg..3,77 g/kg                      <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_ptm_adj   0,01 g/kg/dag..3,77 g/kg/dag              <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.eiwit    dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  orb_qty       0,01 mmol..0,01 mmol..5,18 mmol           <0 ..>
# samenstelling c.Samenstelling C.natrium  cmp_cnc       0,01 mmol/mL                              0,01 mmol/mL
# samenstelling c.Samenstelling C.natrium  orb_cnc       0 mmol/mL..0,5 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.natrium  dos_qty       0,01 mmol..0,01 mmol..5,18 mmol           <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm       0,01 mmol/dag..0,01 mmol/dag..5,18        <0 ..>
#                                                        mmol/dag
# samenstelling c.Samenstelling C.natrium  dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_qty_adj   0 mmol/kg..0,47 mmol/kg                   <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_ptm_adj   0 mmol/kg/dag..0,47 mmol/kg/dag           <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.natrium  dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   orb_qty       0,02 mmol..0,02 mmol..10,4 mmol           <0 ..>
# samenstelling c.Samenstelling C.kalium   cmp_cnc       0,02 mmol/mL                              0,02 mmol/mL
# samenstelling c.Samenstelling C.kalium   orb_cnc       0 mmol/mL..0,5 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.Samenstelling C.kalium   dos_qty       0,02 mmol..0,02 mmol..10,4 mmol           <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm       0,02 mmol/dag..0,02 mmol/dag..10,4        <0 ..>
#                                                        mmol/dag
# samenstelling c.Samenstelling C.kalium   dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_qty_adj   0 mmol/kg..0,94 mmol/kg                   <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_ptm_adj   0 mmol/kg/dag..0,94 mmol/kg/dag           <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.kalium   dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.calcium  cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.calcium  orb_qty       0,03 mmol..0,03 mmol..15,5 mmol           <0 ..>
# samenstelling c.Samenstelling C.calcium  cmp_cnc       0,03 mmol/mL                              0,03 mmol/mL
# samenstelling c.Samenstelling C.calcium  orb_cnc       0 mmol/mL..3,88 mmol/mL                   <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_qty       0,03 mmol..0,03 mmol..15,5 mmol           <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_ptm       0,03 mmol/dag..0,03 mmol/dag..15,5        <0 ..>
#                                                        mmol/dag
# samenstelling c.Samenstelling C.calcium  dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_qty_adj   0 mmol/kg..1,41 mmol/kg                   <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_ptm_adj   0 mmol/kg/dag..1,41 mmol/kg/dag           <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.calcium  dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.fosfaat  cmp_qty       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.fosfaat  orb_qty       0,02 mmol..0,02 mmol..10,4 mmol           <0 ..>
# samenstelling c.Samenstelling C.fosfaat  cmp_cnc       0,02 mmol/mL                              0,02 mmol/mL
# samenstelling c.Samenstelling C.fosfaat  orb_cnc       0 mmol/mL..2,59 mmol/mL                   <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_qty       0,02 mmol..0,02 mmol..10,4 mmol           <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_ptm       0,02 mmol/dag..0,02 mmol/dag..10,4        <0 ..>
#                                                        mmol/dag
# samenstelling c.Samenstelling C.fosfaat  dos_rte       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_tot       <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_qty_adj   0 mmol/kg..0,94 mmol/kg                   <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_ptm_adj   0 mmol/kg/dag..0,94 mmol/kg/dag           <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_rte_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling C.fosfaat  dos_tot_adj   <0 ..>                                    <0 ..>
# samenstelling c.Samenstelling            cmp_qty       <0 ..>                                    <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            orb_qty       0,01 mmol..0,01 mmol..5,18 mmol           <0 ..>
# C.magnesium
# samenstelling c.Samenstelling            cmp_cnc       0,01 mmol/mL                              0,01 mmol/mL
# ...
# samenstelling c.Samenstelling            dos_tot_adj   <0 ..>                          <0 ..>
# C.magnesium
# samenstelling c.Samenstelling C.chloor   cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.Samenstelling C.chloor   orb_qty       25,3 mmol                       <0 ..>
# samenstelling c.Samenstelling C.chloor   cmp_cnc       0,07 mmol/mL                    0,07 mmol/mL
# samenstelling c.Samenstelling C.chloor   orb_cnc       0,04 mmol/mL                    <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_qty       25,3 mmol                       <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_ptm       25,3 mmol/dag                   <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_rte       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_tot       <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_qty_adj   2,3 mmol/kg                     <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_ptm_adj   2,3 mmol/kg/dag                 <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.Samenstelling C.chloor   dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%                  cmp_qty       <0 mL..>                        1 mL
# samenstelling c.NaCl 3%                  orb_qty       22 mL                           1 mL..1 mL..>
# samenstelling c.NaCl 3%                  orb_cnt       <0 x..>                         <0 x..>
# samenstelling c.NaCl 3%                  orb_cnc       0,04 x                          <0 ..>
# samenstelling c.NaCl 3%                  ord_qty       <0 mL..>                        <0 ..>
# samenstelling c.NaCl 3%                  ord_cnt       <0 x..>                         <0 x..>
# samenstelling c.NaCl 3%                  dos_qty       22 mL                           <0 mL..>
# samenstelling c.NaCl 3%                  dos_ptm       22 mL/dag                       <0 ..>
# samenstelling c.NaCl 3%                  dos_rte       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%                  dos_tot       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%                  dos_qty_adj   2 mL/kg                         6 mL/kg
# samenstelling c.NaCl 3%                  dos_ptm_adj   2 mL/kg/dag                     <0 ..>
# samenstelling c.NaCl 3%                  dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%                  dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.NaCl 3%.natrium          orb_qty       11 mmol                         <0 ..>
# samenstelling c.NaCl 3%.natrium          cmp_cnc       0,5 mmol/mL                     0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          orb_cnc       0,02 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.NaCl 3%.natrium          dos_qty       11 mmol                         <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm       11 mmol/dag                     <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_qty_adj   1 mmol/kg                       <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_ptm_adj   1 mmol/kg/dag                   <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.natrium          dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.chloor           cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.NaCl 3%.chloor           orb_qty       11 mmol                         <0 ..>
# samenstelling c.NaCl 3%.chloor           cmp_cnc       0,5 mmol/mL                     0,5 mmol/mL
# samenstelling c.NaCl 3%.chloor           orb_cnc       0,02 mmol/mL                    <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_qty       11 mmol                         <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_ptm       11 mmol/dag                     <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_rte       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_tot       <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_qty_adj   1 mmol/kg                       <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_ptm_adj   1 mmol/kg/dag                   <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.NaCl 3%.chloor           dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%                 cmp_qty       <0 mL..>                        1 mL
# samenstelling c.KCl 7,4%                 orb_qty       42 mL                           1 mL..1 mL..>
# samenstelling c.KCl 7,4%                 orb_cnt       <0 x..>                         <0 x..>
# samenstelling c.KCl 7,4%                 orb_cnc       0,07 x                          <0 ..>
# samenstelling c.KCl 7,4%                 ord_qty       <0 mL..>                        <0 ..>
# samenstelling c.KCl 7,4%                 ord_cnt       <0 x..>                         <0 x..>
# samenstelling c.KCl 7,4%                 dos_qty       42 mL                           <0 mL..>
# samenstelling c.KCl 7,4%                 dos_ptm       42 mL/dag                       <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%                 dos_qty_adj   3,82 mL/kg                      2 mL/kg
# samenstelling c.KCl 7,4%                 dos_ptm_adj   3,82 mL/kg/dag                  <0 ..>
# samenstelling c.KCl 7,4%                 dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%                 dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.KCl 7,4%.kalium          orb_qty       42 mmol                         <0 ..>
# samenstelling c.KCl 7,4%.kalium          cmp_cnc       1 mmol/mL                       1 mmol/mL
# samenstelling c.KCl 7,4%.kalium          orb_cnc       0,07 mmol/mL                    <0 mmol/mL..0,5 mmol/mL
# samenstelling c.KCl 7,4%.kalium          dos_qty       42 mmol                         <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm       42 mmol/dag                     <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_qty_adj   3,82 mmol/kg                    <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_ptm_adj   3,82 mmol/kg/dag                <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.kalium          dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.chloor          cmp_qty       <0 mmol..>                      <0 ..>
# samenstelling c.KCl 7,4%.chloor          orb_qty       42 mmol                         <0 ..>
# samenstelling c.KCl 7,4%.chloor          cmp_cnc       1 mmol/mL                       1 mmol/mL
# samenstelling c.KCl 7,4%.chloor          orb_cnc       0,07 mmol/mL                    <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_qty       42 mmol                         <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_ptm       42 mmol/dag                     <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_rte       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_tot       <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_qty_adj   3,82 mmol/kg                    <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_ptm_adj   3,82 mmol/kg/dag                <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.KCl 7,4%.chloor          dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%                 cmp_qty       <0 mL..>                        1 mL
# samenstelling c.gluc 10%                 orb_qty       156 mL                          1 mL..1 mL..>
# samenstelling c.gluc 10%                 orb_cnt       <0 x..>                         <0 x..>
# samenstelling c.gluc 10%                 orb_cnc       0,27 x                          <0 ..>
# samenstelling c.gluc 10%                 ord_qty       <0 mL..>                        <0 ..>
# samenstelling c.gluc 10%                 ord_cnt       <0 x..>                         <0 x..>
# samenstelling c.gluc 10%                 dos_qty       156 mL                          <0 ..>
# samenstelling c.gluc 10%                 dos_ptm       156 mL/dag                      <0 ..>
# samenstelling c.gluc 10%                 dos_rte       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%                 dos_tot       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%                 dos_qty_adj   14,2 mL/kg                      <0 ..>
# samenstelling c.gluc 10%                 dos_ptm_adj   14,2 mL/kg/dag                  <0 ..>
# samenstelling c.gluc 10%                 dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%                 dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.energie         cmp_qty       <0 kCal..>                      <0 ..>
# samenstelling c.gluc 10%.energie         orb_qty       62,4 kCal                       <0 ..>
# samenstelling c.gluc 10%.energie         cmp_cnc       0,4 kCal/mL                     0,4 kCal/mL
# samenstelling c.gluc 10%.energie         orb_cnc       0,11 kCal/mL                    <0 ..>
# samenstelling c.gluc 10%.energie         dos_qty       62,4 kCal                       <0 ..>
# samenstelling c.gluc 10%.energie         dos_ptm       62,4 kCal/dag                   <0 ..>
# samenstelling c.gluc 10%.energie         dos_rte       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.energie         dos_tot       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.energie         dos_qty_adj   5,67 kCal/kg                    <0 ..>
# samenstelling c.gluc 10%.energie         dos_ptm_adj   5,67 kCal/kg/dag                <0 ..>
# samenstelling c.gluc 10%.energie         dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.energie         dos_tot_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_qty       <0 g..>                         <0 ..>
# samenstelling c.gluc 10%.koolhydraat     orb_qty       15,6 g                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     cmp_cnc       0,1 g/mL                        0,1 g/mL
# samenstelling c.gluc 10%.koolhydraat     orb_cnc       0,03 g/mL                       <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty       15,6 g                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm       15,6 g/dag                      <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot       <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_qty_adj   1,42 g/kg                       <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_ptm_adj   1,42 g/kg/dag                   <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_rte_adj   <0 ..>                          <0 ..>
# samenstelling c.gluc 10%.koolhydraat     dos_tot_adj   <0 ..>                          <0 ..>
#                                          adj_qty       11 kg                           11 kg
